# %%
print(1 != 2)
# Out:
# True

# %%
name = input()
# Out:
# Park

# %%
name
# Out:
# 'Park'

# %%
name=input("What is tyour name?")
# Out:
# What is tyour name?Niemi

# %%
name
# Out:
# 'Niemi'

# %%
print(name)
# Out:
# Niemi

# %%
digit = 1

# %%
digit1 = input()
# Out:
# 1

# %%
digit + bool(digit1)
# Out:
# 2

# %%
digit1=2

# %%
article = """djfgdsaljfha fsdafh sadijfh sdiajf sdaif asiuhf asdiuhf isdajhf ijasdhf jashf jashf jsad fjash fjsd fjksadh fjsdh fjsadh fjsd fjas hfdja f
asdfhg ausifh dasuifh asufh sdjafh askjfh sdjafh asf the ghdsajfhv dsja vas
"""
