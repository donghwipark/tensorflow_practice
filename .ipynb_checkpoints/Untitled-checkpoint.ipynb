# %%
from __future__ import absolute_import, division, print_function, unicode_literals, unicode_literals

import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.1.0

# %%
NUM_WORDS = 10000

(train_data, train_labels), (test_data, test_labels) = keras.datasets.imdb.load_data(num_words=NUM_WORDS)

def multi_hot_sequences(sequences, dimension):
    results = np.zeros((len(sequences), dimension))
    for i, word_indices in enumerate(sequences):
        results[i, word_indices] = 1.0
    return results

train_data = multi_hot_sequences(train_data, dimension=NUM_WORDS)
test_data = multi_hot_sequences(test_data, dimension=NUM_WORDS)

# %%
plt.plot(train_data[0])

# %%
baseline_model = keras.Sequential([
    # `.summary` 메서드 때문에 `input_shape`가 필요합니다
    keras.layers.Dense(16, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

baseline_model.compile(optimizer='adam',
                       loss='binary_crossentropy',
                       metrics=['accuracy', 'binary_crossentropy'])

baseline_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                160016
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 160,305
# Trainable params: 160,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
baseline_history = baseline_model.fit(train_data,
                                      train_labels,
                                      epochs=20,
                                      batch_size=512,
                                      validation_data=(test_data, test_labels),
                                      verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# 25000/25000 - 4s - loss: 0.4616 - accuracy: 0.8184 - binary_crossentropy: 0.4616 - val_loss: 0.3181 - val_accuracy: 0.8793 - val_binary_crossentropy: 0.3181
# Epoch 2/20
# 25000/25000 - 3s - loss: 0.2342 - accuracy: 0.9140 - binary_crossentropy: 0.2342 - val_loss: 0.2814 - val_accuracy: 0.8886 - val_binary_crossentropy: 0.2814
# Epoch 3/20
# 25000/25000 - 3s - loss: 0.1724 - accuracy: 0.9387 - binary_crossentropy: 0.1724 - val_loss: 0.2974 - val_accuracy: 0.8812 - val_binary_crossentropy: 0.2974
# Epoch 4/20
# 25000/25000 - 3s - loss: 0.1359 - accuracy: 0.9543 - binary_crossentropy: 0.1359 - val_loss: 0.3293 - val_accuracy: 0.8776 - val_binary_crossentropy: 0.3293
# Epoch 5/20
# 25000/25000 - 3s - loss: 0.1124 - accuracy: 0.9612 - binary_crossentropy: 0.1124 - val_loss: 0.3615 - val_accuracy: 0.8727 - val_binary_crossentropy: 0.3615
# Epoch 6/20
# 25000/25000 - 3s - loss: 0.0925 - accuracy: 0.9703 - binary_crossentropy: 0.0925 - val_loss: 0.4089 - val_accuracy: 0.8644 - val_binary_crossentropy: 0.4089
# Epoch 7/20
# 25000/25000 - 3s - loss: 0.0755 - accuracy: 0.9780 - binary_crossentropy: 0.0755 - val_loss: 0.4448 - val_accuracy: 0.8630 - val_binary_crossentropy: 0.4448
# Epoch 8/20
# 25000/25000 - 3s - loss: 0.0623 - accuracy: 0.9828 - binary_crossentropy: 0.0623 - val_loss: 0.4883 - val_accuracy: 0.8584 - val_binary_crossentropy: 0.4883
# Epoch 9/20
# 25000/25000 - 3s - loss: 0.0499 - accuracy: 0.9890 - binary_crossentropy: 0.0499 - val_loss: 0.5396 - val_accuracy: 0.8553 - val_binary_crossentropy: 0.5396
# Epoch 10/20
# 25000/25000 - 3s - loss: 0.0397 - accuracy: 0.9917 - binary_crossentropy: 0.0397 - val_loss: 0.5889 - val_accuracy: 0.8543 - val_binary_crossentropy: 0.5889
# Epoch 11/20
# 25000/25000 - 3s - loss: 0.0317 - accuracy: 0.9939 - binary_crossentropy: 0.0317 - val_loss: 0.6376 - val_accuracy: 0.8521 - val_binary_crossentropy: 0.6376
# Epoch 12/20
# 25000/25000 - 3s - loss: 0.0258 - accuracy: 0.9958 - binary_crossentropy: 0.0258 - val_loss: 0.6832 - val_accuracy: 0.8516 - val_binary_crossentropy: 0.6832
# Epoch 13/20
# 25000/25000 - 3s - loss: 0.0196 - accuracy: 0.9976 - binary_crossentropy: 0.0196 - val_loss: 0.7263 - val_accuracy: 0.8501 - val_binary_crossentropy: 0.7263
# Epoch 14/20
# 25000/25000 - 3s - loss: 0.0152 - accuracy: 0.9986 - binary_crossentropy: 0.0152 - val_loss: 0.7670 - val_accuracy: 0.8500 - val_binary_crossentropy: 0.7670
# Epoch 15/20
# 25000/25000 - 3s - loss: 0.0117 - accuracy: 0.9994 - binary_crossentropy: 0.0117 - val_loss: 0.8121 - val_accuracy: 0.8495 - val_binary_crossentropy: 0.8121
# Epoch 16/20
# 25000/25000 - 3s - loss: 0.0088 - accuracy: 0.9998 - binary_crossentropy: 0.0088 - val_loss: 0.8491 - val_accuracy: 0.8486 - val_binary_crossentropy: 0.8491
# Epoch 17/20
# 25000/25000 - 3s - loss: 0.0067 - accuracy: 0.9999 - binary_crossentropy: 0.0067 - val_loss: 0.8810 - val_accuracy: 0.8481 - val_binary_crossentropy: 0.8810
# Epoch 18/20
# 25000/25000 - 3s - loss: 0.0053 - accuracy: 0.9999 - binary_crossentropy: 0.0053 - val_loss: 0.9128 - val_accuracy: 0.8486 - val_binary_crossentropy: 0.9128
# Epoch 19/20
# 25000/25000 - 3s - loss: 0.0043 - accuracy: 1.0000 - binary_crossentropy: 0.0043 - val_loss: 0.9449 - val_accuracy: 0.8483 - val_binary_crossentropy: 0.9449
# Epoch 20/20
# 25000/25000 - 3s - loss: 0.0036 - accuracy: 1.0000 - binary_crossentropy: 0.0036 - val_loss: 0.9742 - val_accuracy: 0.8479 - val_binary_crossentropy: 0.9742

# %%
smaller_model = keras.Sequential([
    keras.layers.Dense(4, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(4, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

smaller_model.compile(optimizer='adam',
                      loss='binary_crossentropy',
                      metrics=['accuracy', 'binary_crossentropy'])

smaller_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 4)                 40004
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 40,029
# Trainable params: 40,029
# Non-trainable params: 0
# _________________________________________________________________

# %%
smaller_history = smaller_model.fit(train_data,
                                    train_labels,
                                    epochs=20,
                                    batch_size=512,
                                    validation_data=(test_data, test_labels),
                                    verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# 25000/25000 - 3s - loss: 0.6047 - accuracy: 0.7567 - binary_crossentropy: 0.6047 - val_loss: 0.5057 - val_accuracy: 0.8410 - val_binary_crossentropy: 0.5057
# Epoch 2/20
# 25000/25000 - 2s - loss: 0.4106 - accuracy: 0.8740 - binary_crossentropy: 0.4106 - val_loss: 0.3780 - val_accuracy: 0.8690 - val_binary_crossentropy: 0.3780
# Epoch 3/20
# 25000/25000 - 2s - loss: 0.3041 - accuracy: 0.9003 - binary_crossentropy: 0.3041 - val_loss: 0.3205 - val_accuracy: 0.8799 - val_binary_crossentropy: 0.3205
# Epoch 4/20
# 25000/25000 - 2s - loss: 0.2470 - accuracy: 0.9163 - binary_crossentropy: 0.2470 - val_loss: 0.2973 - val_accuracy: 0.8846 - val_binary_crossentropy: 0.2973
# Epoch 5/20
# 25000/25000 - 2s - loss: 0.2114 - accuracy: 0.9275 - binary_crossentropy: 0.2114 - val_loss: 0.2843 - val_accuracy: 0.8876 - val_binary_crossentropy: 0.2843
# Epoch 6/20
# 25000/25000 - 2s - loss: 0.1858 - accuracy: 0.9366 - binary_crossentropy: 0.1858 - val_loss: 0.2865 - val_accuracy: 0.8850 - val_binary_crossentropy: 0.2865
# Epoch 7/20
# 25000/25000 - 3s - loss: 0.1658 - accuracy: 0.9451 - binary_crossentropy: 0.1658 - val_loss: 0.2883 - val_accuracy: 0.8840 - val_binary_crossentropy: 0.2883
# Epoch 8/20
# 25000/25000 - 2s - loss: 0.1490 - accuracy: 0.9514 - binary_crossentropy: 0.1490 - val_loss: 0.2907 - val_accuracy: 0.8858 - val_binary_crossentropy: 0.2907
# Epoch 9/20
# 25000/25000 - 2s - loss: 0.1353 - accuracy: 0.9563 - binary_crossentropy: 0.1353 - val_loss: 0.2990 - val_accuracy: 0.8836 - val_binary_crossentropy: 0.2990
# Epoch 10/20
# 25000/25000 - 2s - loss: 0.1233 - accuracy: 0.9609 - binary_crossentropy: 0.1233 - val_loss: 0.3125 - val_accuracy: 0.8793 - val_binary_crossentropy: 0.3125
# Epoch 11/20
# 25000/25000 - 2s - loss: 0.1129 - accuracy: 0.9648 - binary_crossentropy: 0.1129 - val_loss: 0.3214 - val_accuracy: 0.8776 - val_binary_crossentropy: 0.3214
# Epoch 12/20
# 25000/25000 - 2s - loss: 0.1028 - accuracy: 0.9688 - binary_crossentropy: 0.1028 - val_loss: 0.3376 - val_accuracy: 0.8746 - val_binary_crossentropy: 0.3376
# Epoch 13/20
# 25000/25000 - 2s - loss: 0.0944 - accuracy: 0.9714 - binary_crossentropy: 0.0944 - val_loss: 0.3518 - val_accuracy: 0.8731 - val_binary_crossentropy: 0.3518
# Epoch 14/20
# 25000/25000 - 3s - loss: 0.0867 - accuracy: 0.9743 - binary_crossentropy: 0.0867 - val_loss: 0.3711 - val_accuracy: 0.8699 - val_binary_crossentropy: 0.3711
# Epoch 15/20
# 25000/25000 - 3s - loss: 0.0798 - accuracy: 0.9788 - binary_crossentropy: 0.0798 - val_loss: 0.3836 - val_accuracy: 0.8698 - val_binary_crossentropy: 0.3836
# Epoch 16/20
# 25000/25000 - 3s - loss: 0.0725 - accuracy: 0.9807 - binary_crossentropy: 0.0725 - val_loss: 0.3998 - val_accuracy: 0.8686 - val_binary_crossentropy: 0.3998
# Epoch 17/20
# 25000/25000 - 3s - loss: 0.0666 - accuracy: 0.9838 - binary_crossentropy: 0.0666 - val_loss: 0.4183 - val_accuracy: 0.8671 - val_binary_crossentropy: 0.4183
# Epoch 18/20
# 25000/25000 - 3s - loss: 0.0604 - accuracy: 0.9862 - binary_crossentropy: 0.0604 - val_loss: 0.4391 - val_accuracy: 0.8650 - val_binary_crossentropy: 0.4391
# Epoch 19/20
# 25000/25000 - 3s - loss: 0.0552 - accuracy: 0.9888 - binary_crossentropy: 0.0552 - val_loss: 0.4647 - val_accuracy: 0.8621 - val_binary_crossentropy: 0.4647
# Epoch 20/20
# 25000/25000 - 3s - loss: 0.0508 - accuracy: 0.9898 - binary_crossentropy: 0.0508 - val_loss: 0.4762 - val_accuracy: 0.8623 - val_binary_crossentropy: 0.4762

# %%
bigger_model = keras.models.Sequential([
    keras.layers.Dense(512, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(512, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

bigger_model.compile(optimizer='adam',
                     loss='binary_crossentropy',
                     metrics=['accuracy','binary_crossentropy'])

bigger_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 512)               5120512
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 5,383,681
# Trainable params: 5,383,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
bigger_history = bigger_model.fit(train_data, train_labels,
                                  epochs=20,
                                  batch_size=512,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# 25000/25000 - 25s - loss: 0.3436 - accuracy: 0.8566 - binary_crossentropy: 0.3436 - val_loss: 0.2912 - val_accuracy: 0.8810 - val_binary_crossentropy: 0.2912
# Epoch 2/20
# 25000/25000 - 23s - loss: 0.1398 - accuracy: 0.9490 - binary_crossentropy: 0.1398 - val_loss: 0.3314 - val_accuracy: 0.8711 - val_binary_crossentropy: 0.3314
# Epoch 3/20
# 25000/25000 - 28s - loss: 0.0439 - accuracy: 0.9870 - binary_crossentropy: 0.0439 - val_loss: 0.4517 - val_accuracy: 0.8679 - val_binary_crossentropy: 0.4517
# Epoch 4/20
# 25000/25000 - 24s - loss: 0.0063 - accuracy: 0.9992 - binary_crossentropy: 0.0063 - val_loss: 0.6050 - val_accuracy: 0.8695 - val_binary_crossentropy: 0.6050
# Epoch 5/20
# 25000/25000 - 26s - loss: 0.0013 - accuracy: 0.9999 - binary_crossentropy: 0.0013 - val_loss: 0.6928 - val_accuracy: 0.8707 - val_binary_crossentropy: 0.6928
# Epoch 6/20
# 25000/25000 - 23s - loss: 2.3610e-04 - accuracy: 1.0000 - binary_crossentropy: 2.3610e-04 - val_loss: 0.7433 - val_accuracy: 0.8702 - val_binary_crossentropy: 0.7433
# Epoch 7/20
# 25000/25000 - 25s - loss: 1.3591e-04 - accuracy: 1.0000 - binary_crossentropy: 1.3591e-04 - val_loss: 0.7763 - val_accuracy: 0.8706 - val_binary_crossentropy: 0.7763
# Epoch 8/20
# 25000/25000 - 34s - loss: 9.7057e-05 - accuracy: 1.0000 - binary_crossentropy: 9.7057e-05 - val_loss: 0.8026 - val_accuracy: 0.8704 - val_binary_crossentropy: 0.8026
# Epoch 9/20
# 25000/25000 - 28s - loss: 7.4091e-05 - accuracy: 1.0000 - binary_crossentropy: 7.4091e-05 - val_loss: 0.8222 - val_accuracy: 0.8707 - val_binary_crossentropy: 0.8222
# Epoch 10/20
# 25000/25000 - 22s - loss: 5.8839e-05 - accuracy: 1.0000 - binary_crossentropy: 5.8839e-05 - val_loss: 0.8403 - val_accuracy: 0.8708 - val_binary_crossentropy: 0.8403
# Epoch 11/20
# 25000/25000 - 23s - loss: 4.8013e-05 - accuracy: 1.0000 - binary_crossentropy: 4.8013e-05 - val_loss: 0.8552 - val_accuracy: 0.8711 - val_binary_crossentropy: 0.8552
# Epoch 12/20
# 25000/25000 - 22s - loss: 4.0013e-05 - accuracy: 1.0000 - binary_crossentropy: 4.0013e-05 - val_loss: 0.8697 - val_accuracy: 0.8710 - val_binary_crossentropy: 0.8697
# Epoch 13/20
# 25000/25000 - 24s - loss: 3.3815e-05 - accuracy: 1.0000 - binary_crossentropy: 3.3815e-05 - val_loss: 0.8835 - val_accuracy: 0.8706 - val_binary_crossentropy: 0.8835
# Epoch 14/20
# 25000/25000 - 24s - loss: 2.8932e-05 - accuracy: 1.0000 - binary_crossentropy: 2.8932e-05 - val_loss: 0.8955 - val_accuracy: 0.8708 - val_binary_crossentropy: 0.8955
# Epoch 15/20
# 25000/25000 - 22s - loss: 2.4996e-05 - accuracy: 1.0000 - binary_crossentropy: 2.4996e-05 - val_loss: 0.9067 - val_accuracy: 0.8708 - val_binary_crossentropy: 0.9067
# Epoch 16/20
# 25000/25000 - 23s - loss: 2.1790e-05 - accuracy: 1.0000 - binary_crossentropy: 2.1790e-05 - val_loss: 0.9176 - val_accuracy: 0.8706 - val_binary_crossentropy: 0.9176
# Epoch 17/20
# 25000/25000 - 23s - loss: 1.9146e-05 - accuracy: 1.0000 - binary_crossentropy: 1.9146e-05 - val_loss: 0.9271 - val_accuracy: 0.8707 - val_binary_crossentropy: 0.9271
# Epoch 18/20
# 25000/25000 - 22s - loss: 1.6932e-05 - accuracy: 1.0000 - binary_crossentropy: 1.6932e-05 - val_loss: 0.9372 - val_accuracy: 0.8706 - val_binary_crossentropy: 0.9372
# Epoch 19/20
# 25000/25000 - 24s - loss: 1.5052e-05 - accuracy: 1.0000 - binary_crossentropy: 1.5052e-05 - val_loss: 0.9463 - val_accuracy: 0.8706 - val_binary_crossentropy: 0.9463
# Epoch 20/20
# 25000/25000 - 23s - loss: 1.3448e-05 - accuracy: 1.0000 - binary_crossentropy: 1.3448e-05 - val_loss: 0.9551 - val_accuracy: 0.8707 - val_binary_crossentropy: 0.9551

# %%
l2_model = keras.models.Sequential([
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                       activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                       activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

l2_model.compile(optimizer='adam',
                 loss='binary_crossentropy',
                 metrics=['accuracy', 'binary_crossentropy'])

l2_model_history = l2_model.fit(train_data, train_labels,
                                epochs=20,
                                batch_size=512,
                                validation_data=(test_data, test_labels),
                                verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# 25000/25000 - 4s - loss: 0.5524 - accuracy: 0.8066 - binary_crossentropy: 0.5132 - val_loss: 0.4099 - val_accuracy: 0.8687 - val_binary_crossentropy: 0.3678
# Epoch 2/20
# 25000/25000 - 3s - loss: 0.3291 - accuracy: 0.9014 - binary_crossentropy: 0.2807 - val_loss: 0.3442 - val_accuracy: 0.8870 - val_binary_crossentropy: 0.2913
# Epoch 3/20
# 25000/25000 - 3s - loss: 0.2732 - accuracy: 0.9238 - binary_crossentropy: 0.2175 - val_loss: 0.3414 - val_accuracy: 0.8869 - val_binary_crossentropy: 0.2838
# Epoch 4/20
# 25000/25000 - 3s - loss: 0.2483 - accuracy: 0.9326 - binary_crossentropy: 0.1891 - val_loss: 0.3467 - val_accuracy: 0.8846 - val_binary_crossentropy: 0.2864
# Epoch 5/20
# 25000/25000 - 3s - loss: 0.2327 - accuracy: 0.9416 - binary_crossentropy: 0.1712 - val_loss: 0.3600 - val_accuracy: 0.8801 - val_binary_crossentropy: 0.2981
# Epoch 6/20
# 25000/25000 - 3s - loss: 0.2206 - accuracy: 0.9471 - binary_crossentropy: 0.1576 - val_loss: 0.3700 - val_accuracy: 0.8793 - val_binary_crossentropy: 0.3066
# Epoch 7/20
# 25000/25000 - 3s - loss: 0.2126 - accuracy: 0.9499 - binary_crossentropy: 0.1485 - val_loss: 0.3800 - val_accuracy: 0.8760 - val_binary_crossentropy: 0.3157
# Epoch 8/20
# 25000/25000 - 3s - loss: 0.2045 - accuracy: 0.9521 - binary_crossentropy: 0.1398 - val_loss: 0.3917 - val_accuracy: 0.8726 - val_binary_crossentropy: 0.3266
# Epoch 9/20
# 25000/25000 - 3s - loss: 0.2003 - accuracy: 0.9538 - binary_crossentropy: 0.1345 - val_loss: 0.4025 - val_accuracy: 0.8725 - val_binary_crossentropy: 0.3363
# Epoch 10/20
# 25000/25000 - 3s - loss: 0.1946 - accuracy: 0.9558 - binary_crossentropy: 0.1280 - val_loss: 0.4231 - val_accuracy: 0.8674 - val_binary_crossentropy: 0.3561
# Epoch 11/20
# 25000/25000 - 3s - loss: 0.1901 - accuracy: 0.9576 - binary_crossentropy: 0.1227 - val_loss: 0.4302 - val_accuracy: 0.8664 - val_binary_crossentropy: 0.3625
# Epoch 12/20
# 25000/25000 - 3s - loss: 0.1863 - accuracy: 0.9606 - binary_crossentropy: 0.1182 - val_loss: 0.4354 - val_accuracy: 0.8669 - val_binary_crossentropy: 0.3670
# Epoch 13/20
# 25000/25000 - 3s - loss: 0.1848 - accuracy: 0.9592 - binary_crossentropy: 0.1159 - val_loss: 0.4513 - val_accuracy: 0.8660 - val_binary_crossentropy: 0.3823
# Epoch 14/20
# 25000/25000 - 3s - loss: 0.1782 - accuracy: 0.9632 - binary_crossentropy: 0.1089 - val_loss: 0.4541 - val_accuracy: 0.8648 - val_binary_crossentropy: 0.3846
# Epoch 15/20
# 25000/25000 - 3s - loss: 0.1743 - accuracy: 0.9641 - binary_crossentropy: 0.1046 - val_loss: 0.4675 - val_accuracy: 0.8634 - val_binary_crossentropy: 0.3978
# Epoch 16/20
# 25000/25000 - 3s - loss: 0.1728 - accuracy: 0.9645 - binary_crossentropy: 0.1029 - val_loss: 0.4810 - val_accuracy: 0.8614 - val_binary_crossentropy: 0.4106
# Epoch 17/20
# 25000/25000 - 3s - loss: 0.1691 - accuracy: 0.9659 - binary_crossentropy: 0.0986 - val_loss: 0.4903 - val_accuracy: 0.8607 - val_binary_crossentropy: 0.4198
# Epoch 18/20
# 25000/25000 - 3s - loss: 0.1653 - accuracy: 0.9683 - binary_crossentropy: 0.0948 - val_loss: 0.5009 - val_accuracy: 0.8582 - val_binary_crossentropy: 0.4305
# Epoch 19/20
# 25000/25000 - 3s - loss: 0.1608 - accuracy: 0.9704 - binary_crossentropy: 0.0902 - val_loss: 0.5122 - val_accuracy: 0.8561 - val_binary_crossentropy: 0.4418
# Epoch 20/20
# 25000/25000 - 3s - loss: 0.1599 - accuracy: 0.9704 - binary_crossentropy: 0.0891 - val_loss: 0.5148 - val_accuracy: 0.8571 - val_binary_crossentropy: 0.4439

# %%
plot_history([('baseline', baseline_history),('l2', l2_model_history)])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-68703f256fa5> in <module>
# ----> 1 plot_history([('baseline', baseline_history),('l2', l2_model_history)])
#
# NameError: name 'plot_history' is not defined

# %%
dpt_model = keras.models.Sequential([
    keras.layers.Dense(16, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1, activation='sigmoid')
])

dpt_model.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy','binary_crossentropy'])

dpt_model_history = dpt_model.fit(train_data, train_labels,
                                  epochs=20,
                                  batch_size=512,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# 25000/25000 - 4s - loss: 0.6512 - accuracy: 0.6192 - binary_crossentropy: 0.6512 - val_loss: 0.5970 - val_accuracy: 0.7912 - val_binary_crossentropy: 0.5970
# Epoch 2/20
# 25000/25000 - 3s - loss: 0.5498 - accuracy: 0.7690 - binary_crossentropy: 0.5498 - val_loss: 0.4896 - val_accuracy: 0.8683 - val_binary_crossentropy: 0.4896
# Epoch 3/20
# 25000/25000 - 3s - loss: 0.4650 - accuracy: 0.8488 - binary_crossentropy: 0.4650 - val_loss: 0.4178 - val_accuracy: 0.8820 - val_binary_crossentropy: 0.4178
# Epoch 4/20
# 25000/25000 - 3s - loss: 0.3990 - accuracy: 0.8870 - binary_crossentropy: 0.3990 - val_loss: 0.3735 - val_accuracy: 0.8830 - val_binary_crossentropy: 0.3735
# Epoch 5/20
# 25000/25000 - 3s - loss: 0.3525 - accuracy: 0.9036 - binary_crossentropy: 0.3525 - val_loss: 0.3502 - val_accuracy: 0.8826 - val_binary_crossentropy: 0.3502
# Epoch 6/20
# 25000/25000 - 3s - loss: 0.3148 - accuracy: 0.9168 - binary_crossentropy: 0.3148 - val_loss: 0.3382 - val_accuracy: 0.8835 - val_binary_crossentropy: 0.3382
# Epoch 7/20
# 25000/25000 - 3s - loss: 0.2863 - accuracy: 0.9271 - binary_crossentropy: 0.2863 - val_loss: 0.3333 - val_accuracy: 0.8816 - val_binary_crossentropy: 0.3333
# Epoch 8/20
# 25000/25000 - 3s - loss: 0.2627 - accuracy: 0.9318 - binary_crossentropy: 0.2627 - val_loss: 0.3379 - val_accuracy: 0.8820 - val_binary_crossentropy: 0.3379
# Epoch 9/20
# 25000/25000 - 3s - loss: 0.2444 - accuracy: 0.9366 - binary_crossentropy: 0.2444 - val_loss: 0.3437 - val_accuracy: 0.8802 - val_binary_crossentropy: 0.3437
# Epoch 10/20
# 25000/25000 - 3s - loss: 0.2283 - accuracy: 0.9428 - binary_crossentropy: 0.2283 - val_loss: 0.3577 - val_accuracy: 0.8786 - val_binary_crossentropy: 0.3577
# Epoch 11/20
# 25000/25000 - 3s - loss: 0.2105 - accuracy: 0.9478 - binary_crossentropy: 0.2105 - val_loss: 0.3685 - val_accuracy: 0.8772 - val_binary_crossentropy: 0.3685
# Epoch 12/20
# 25000/25000 - 3s - loss: 0.1989 - accuracy: 0.9518 - binary_crossentropy: 0.1989 - val_loss: 0.3851 - val_accuracy: 0.8771 - val_binary_crossentropy: 0.3851
# Epoch 13/20
# 25000/25000 - 3s - loss: 0.1894 - accuracy: 0.9546 - binary_crossentropy: 0.1894 - val_loss: 0.4151 - val_accuracy: 0.8753 - val_binary_crossentropy: 0.4151
# Epoch 14/20
# 25000/25000 - 3s - loss: 0.1786 - accuracy: 0.9575 - binary_crossentropy: 0.1786 - val_loss: 0.4164 - val_accuracy: 0.8762 - val_binary_crossentropy: 0.4164
# Epoch 15/20
# 25000/25000 - 2s - loss: 0.1683 - accuracy: 0.9613 - binary_crossentropy: 0.1683 - val_loss: 0.4338 - val_accuracy: 0.8753 - val_binary_crossentropy: 0.4338
# Epoch 16/20
# 25000/25000 - 3s - loss: 0.1623 - accuracy: 0.9620 - binary_crossentropy: 0.1623 - val_loss: 0.4857 - val_accuracy: 0.8762 - val_binary_crossentropy: 0.4857
# Epoch 17/20
# 25000/25000 - 3s - loss: 0.1548 - accuracy: 0.9642 - binary_crossentropy: 0.1548 - val_loss: 0.4532 - val_accuracy: 0.8729 - val_binary_crossentropy: 0.4532
# Epoch 18/20
# 25000/25000 - 3s - loss: 0.1487 - accuracy: 0.9663 - binary_crossentropy: 0.1487 - val_loss: 0.4960 - val_accuracy: 0.8745 - val_binary_crossentropy: 0.4960
# Epoch 19/20
# 25000/25000 - 3s - loss: 0.1469 - accuracy: 0.9652 - binary_crossentropy: 0.1469 - val_loss: 0.5183 - val_accuracy: 0.8724 - val_binary_crossentropy: 0.5183
# Epoch 20/20
# 25000/25000 - 3s - loss: 0.1414 - accuracy: 0.9683 - binary_crossentropy: 0.1414 - val_loss: 0.5419 - val_accuracy: 0.8752 - val_binary_crossentropy: 0.5419

# %%
plot_history([('baseline', baseline_history),
              ('dropout', dpt_model_history)])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-8f3bc18f2756> in <module>
# ----> 1 plot_history([('baseline', baseline_history),
#       2               ('dropout', dpt_model_history)])
#
# NameError: name 'plot_history' is not defined
