# %%
def func1 ():
    print("hello")

# %%
func1()
# Out:
# hello

# %%
def func1 (name):
    print("hello " + name)

# %%
func1("park")
# Out:
# hello park

# %%
def func2(data1, data2):
    return data1 + data2

# %%
func2(1, 2)
# Out:
# 3

# %%
arr1 = [1, 2, 3]
arr2 = [4, 5, 6]

# %%
arr1 + arr2
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
arr1
# Out:
# [1, 2, 3]

# %%
x = 1

# %%
y = 2

# %%
(x, y) = (y, x)

# %%
x
# Out:
# 2

# %%
y
# Out:
# 1

# %%
data = (1, 2, 3)

# %%
type(data)
# Out:
# tuple

# %%
type(list(data))
# Out:
# list

# %%
data
# Out:
# (1, 2, 3)

# %%
obj1 = dict()

# %%
obj1
# Out:
# {}

# %%
obj1['US'] = '미국'

# %%
obj1
# Out:
# {'US': '미국'}

# %%
del obj1['US']

# %%
obj1
# Out:
# {}

# %%
'미국' in obj1
# Out:
# False

# %%
obj1['US'] = '미국'

# %%
set1 = { 'a', 'b', 'c'}

# %%
set2 = {'b', 'c', 'd'}

# %%
set1 & set2
# Out:
# {'b', 'c'}

# %%
set1 | set2
# Out:
# {'a', 'b', 'c', 'd'}

# %%
set1 - set2
# Out:
# {'a'}
